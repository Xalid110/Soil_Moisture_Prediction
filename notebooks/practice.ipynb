# %%
# %run ../src/pipeline.py --mode incremental
# Out:
# 🚀 Starting Weather Pipeline in 'INCREMENTAL' mode.
# STAGE 1: Data Ingestion
# 📥 Fetching Zerdab from 2026-04-15 to 2026-04-24...
# 📥 Fetching Quba from 2026-04-15 to 2026-04-24...
# 📥 Fetching Lenkeran from 2026-04-15 to 2026-04-24...
# 📥 Fetching Baki from 2026-04-15 to 2026-04-24...
# 📥 Fetching Saatli from 2026-04-15 to 2026-04-24...
# STAGE 2: Loading to DuckDB Raw Layer
# ✅ Raw table contains 85 total rows.
# STAGE 3: Cleaning (Raw -> Staging)
# STAGE 4: Feature Engineering (Staging -> Analytics)
# STAGE 5: Running Quality Checks
# 🎉 Pipeline completed successfully in 2.39 seconds.
# 🔄 Cleaning data from raw.weather_daily ...
# 📥 Raw data loaded: 85 rows, 15 columns
#
# 📅 Date continuity summary:
#        city start_date   end_date  expected_days  actual_days  missing_days  \
# 0      Baki 2026-04-15 2026-05-01             17           17             0
# 1  Lenkeran 2026-04-15 2026-05-01             17           17             0
# 2      Quba 2026-04-15 2026-05-01             17           17             0
# 3    Saatli 2026-04-15 2026-05-01             17           17             0
# 4    Zerdab 2026-04-15 2026-05-01             17           17             0
#
#   missing_list
# 0           []
# 1           []
# 2           []
# 3           []
# 4           []
#
# ✅ Cleaned data written to staging.weather_daily
# 📊 Sample of cleaned data:
# city       date  temperature_2m_mean  et0_fao_evapotranspiration_sum  sunshine_duration  shortwave_radiation_sum  relative_humidity_2m_mean  surface_pressure_mean  precipitation_sum  precipitation_hours  wind_speed_10m_max  cloud_cover_mean  wind_gusts_10m_mean  soil_moisture_0_to_7cm_mean  data_type
# Baki 2026-04-15            11.702085                        3.136395       41735.414062                20.240000                  69.572823            1024.161987                0.3                  3.0           15.484185         47.250000            28.199997                     0.277208 historical
# Baki 2026-04-16            13.097917                        3.106966       42755.191406                19.440001                  65.637993            1023.956787                0.0                  0.0           12.362475         20.416666            14.085001                     0.260625 historical
# Baki 2026-04-17            12.995834                        3.021810       42742.210938                21.790001                  80.436111            1024.379028                0.0                  0.0           16.036171         22.750000            25.874998                     0.239250 historical
# Baki 2026-04-18            13.668750                        2.861732       43815.843750                22.580000                  83.649406            1016.915588                0.0                  0.0           22.350464         27.541666            38.280003                     0.212958 historical
# Baki 2026-04-19            15.177083                        3.267373       41231.125000                21.450001                  80.289223            1006.191345                0.1                  1.0           20.803045         51.625000            34.079998                     0.188708 historical
# 🔧 Generating features from staging.weather_daily ...
# ✅ Features computed: day_of_year, precip_sum_7d, prev_soil_moisture
#
# Data now has 85 rows and 18 columns.
#
# 📊 Example of engineered data:
# city       date  temperature_2m_mean  et0_fao_evapotranspiration_sum  sunshine_duration  shortwave_radiation_sum  relative_humidity_2m_mean  surface_pressure_mean  precipitation_sum  precipitation_hours  wind_speed_10m_max  cloud_cover_mean  wind_gusts_10m_mean  soil_moisture_0_to_7cm_mean  data_type  day_of_year  precip_sum_7d  prev_soil_moisture
# Baki 2026-04-15            11.702085                        3.136395       41735.414062                20.240000                  69.572823            1024.161987                0.3                  3.0           15.484185         47.250000            28.199997                     0.277208 historical          105            0.3                 NaN
# Baki 2026-04-16            13.097917                        3.106966       42755.191406                19.440001                  65.637993            1023.956787                0.0                  0.0           12.362475         20.416666            14.085001                     0.260625 historical          106            0.3            0.277208
# Baki 2026-04-17            12.995834                        3.021810       42742.210938                21.790001                  80.436111            1024.379028                0.0                  0.0           16.036171         22.750000            25.874998                     0.239250 historical          107            0.3            0.260625
# Baki 2026-04-18            13.668750                        2.861732       43815.843750                22.580000                  83.649406            1016.915588                0.0                  0.0           22.350464         27.541666            38.280003                     0.212958 historical          108            0.3            0.239250
# Baki 2026-04-19            15.177083                        3.267373       41231.125000                21.450001                  80.289223            1006.191345                0.1                  1.0           20.803045         51.625000            34.079998                     0.188708 historical          109            0.4            0.212958
# Baki 2026-04-20            13.847917                        2.064010        8520.239258                 9.200000                  76.577911            1011.642517                1.8                  6.0           24.725605         95.208336            47.235001                     0.188417 historical          110            2.2            0.188708
# Baki 2026-04-21            10.787499                        1.553613       13218.458984                 9.220000                  83.323708            1015.477234                6.4                 11.0           22.158285         75.750000            38.565002                     0.244083 historical          111            8.6            0.188417
# Baki 2026-04-22            13.112499                        3.127617       43021.062500                20.930000                  80.909668            1013.233398                0.0                  0.0           18.501513         51.833332            25.094997                     0.240625 historical          112            8.3            0.244083
# Baki 2026-04-23            12.887501                        1.882021       21648.394531                13.040000                  86.022186            1011.448242                0.1                  1.0           19.380743         58.000000            29.189997                     0.225250 historical          113            8.4            0.240625
# Baki 2026-04-24            12.620833                        3.192160       38318.058594                22.530001                  86.677086            1009.776367                0.0                  0.0           18.194254         39.458332            23.985001                     0.212583 historical          114            8.4            0.225250
#
# ✅ Features written to analytics.weather_features.
#
# ==================================================
# 📊 DATA QUALITY REPORT
# ==================================================
#     stage                  check_name status                    details
#       Raw               Row count > 0   PASS             85 rows loaded
#   Staging             Null ratio < 5%   PASS     All columns < 5% nulls
#   Staging            No gaps > 3 days   PASS    Max gap found: 1.0 days
#   Staging Temperature range [-50, 60]   PASS     0 invalid rows flagged
# Analytics        Feature completeness   PASS       All features present
#       Raw   Freshness (within 2 days)   PASS Latest data is -6 days old
# ==================================================

# %%
import duckdb
import pandas as pd

# 1. Connect to your local database
conn = duckdb.connect('../data/weather_pipeline.duckdb')

# 2. Query the gold-standard analytics layer
query = "SELECT * FROM analytics.weather_features"
df_ml = conn.execute(query).df()

# 3. Always close the connection when done fetching
conn.close()

# Let's see the data ready for modeling!
df_ml
# Out:
#       city       date  temperature_2m_mean  et0_fao_evapotranspiration_sum  \
# 0     Baki 2026-04-15            11.702085                        3.136395
# 1     Baki 2026-04-16            13.097917                        3.106966
# 2     Baki 2026-04-17            12.995834                        3.021810
# 3     Baki 2026-04-18            13.668750                        2.861732
# 4     Baki 2026-04-19            15.177083                        3.267373
# ..     ...        ...                  ...                             ...
# 80  Zerdab 2026-04-27            16.587751                        3.001373
# 81  Zerdab 2026-04-28            15.056499                        2.285249
# 82  Zerdab 2026-04-29            13.214835                        2.008758
# 83  Zerdab 2026-04-30            15.764396                        4.454700
# 84  Zerdab 2026-05-01            16.397665                        4.519802
#
#     sunshine_duration  shortwave_radiation_sum  relative_humidity_2m_mean  \
# 0        41735.414062                20.240000                  69.572823
# 1        42755.191406                19.440001                  65.637993
# 2        42742.210938                21.790001                  80.436111
# 3        43815.843750                22.580000                  83.649406
# 4        41231.125000                21.450001                  80.289223
# ..                ...                      ...                        ...
# 80       24620.333984                15.740000                  73.166664
# 81           0.000000                 6.260000                  64.125000
# 82        7326.495605                10.980000                  59.666668
# 83       47737.687500                24.490000                  61.541668
# 84       47630.242188                25.430000                  60.875000
#
#     surface_pressure_mean  precipitation_sum  precipitation_hours  \
# 0             1024.161987                0.3                  3.0
# 1             1023.956787                0.0                  0.0
# 2             1024.379028                0.0                  0.0
# 3             1016.915588                0.0                  0.0
# 4             1006.191345                0.1                  1.0
# ..                    ...                ...                  ...
# 80            1011.706299                0.0                  0.0
# 81            1018.837158                1.2                  4.0
# 82            1019.444641                0.0                  0.0
# 83            1018.431641                0.0                  0.0
# 84            1017.863831                0.0                  0.0
#
#     wind_speed_10m_max  cloud_cover_mean  wind_gusts_10m_mean  \
# 0            15.484185         47.250000            28.199997
# 1            12.362475         20.416666            14.085001
# 2            16.036171         22.750000            25.874998
# 3            22.350464         27.541666            38.280003
# 4            20.803045         51.625000            34.079998
# ..                 ...               ...                  ...
# 80           16.263872         72.166664            16.829998
# 81           22.264771         96.791664            26.579998
# 82            9.565437         97.250000             9.480000
# 83           16.418526         60.375000            13.323749
# 84           11.770403         27.625000            13.440001
#
#     soil_moisture_0_to_7cm_mean   data_type  day_of_year  precip_sum_7d  \
# 0                      0.277208  historical          105            0.3
# 1                      0.260625  historical          106            0.3
# 2                      0.239250  historical          107            0.3
# 3                      0.212958  historical          108            0.3
# 4                      0.188708  historical          109            0.4
# ..                          ...         ...          ...            ...
# 80                     0.207500    forecast          117           11.6
# 81                     0.196042    forecast          118            1.3
# 82                     0.204542    forecast          119            1.3
# 83                     0.199833    forecast          120            1.2
# 84                     0.183083    forecast          121            1.2
#
#     prev_soil_moisture
# 0                  NaN
# 1             0.277208
# 2             0.260625
# 3             0.239250
# 4             0.212958
# ..                 ...
# 80            0.220083
# 81            0.207500
# 82            0.196042
# 83            0.204542
# 84            0.199833
#
# [85 rows x 18 columns]

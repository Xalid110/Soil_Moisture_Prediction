# %%
import os
import glob

# Find and delete the old _inference files
old_files = glob.glob('../data/raw/*_inference.parquet')
for file in old_files:
    os.remove(file)
    print(f"Deleted: {file}")

# %%
# Run the pipeline in FULL mode
# !python ../src/pipeline.py --mode full
# Out:
# 🚀 Starting Weather Pipeline in 'FULL' mode.
# STAGE 1: Data Ingestion
# 📥 Fetching Zerdab from 2026-04-14 to 2026-04-23...
# 📥 Fetching Quba from 2026-04-14 to 2026-04-23...
# 📥 Fetching Lenkeran from 2026-04-14 to 2026-04-23...
# 📥 Fetching Baki from 2026-04-14 to 2026-04-23...
# 📥 Fetching Saatli from 2026-04-14 to 2026-04-23...
# STAGE 2: Loading to DuckDB Raw Layer
# ✅ Raw table contains 85 total rows.
# STAGE 3: Cleaning (Raw -> Staging)
# 🔄 Cleaning data from raw.weather_daily ...
# 📥 Raw data loaded: 85 rows, 15 columns
#
# 📅 Date continuity summary:
#        city start_date   end_date  ...  actual_days  missing_days  missing_list
# 0      Baki 2026-04-14 2026-04-30  ...           17             0            []
# 1  Lenkeran 2026-04-14 2026-04-30  ...           17             0            []
# 2      Quba 2026-04-14 2026-04-30  ...           17             0            []
# 3    Saatli 2026-04-14 2026-04-30  ...           17             0            []
# 4    Zerdab 2026-04-14 2026-04-30  ...           17             0            []
#
# [5 rows x 7 columns]
#
# ✅ Cleaned data written to staging.weather_daily
# 📊 Sample of cleaned data:
# city       date  temperature_2m_mean  et0_fao_evapotranspiration_sum  sunshine_duration  shortwave_radiation_sum  relative_humidity_2m_mean  surface_pressure_mean  precipitation_sum  precipitation_hours  wind_speed_10m_max  cloud_cover_mean  wind_gusts_10m_mean  soil_moisture_0_to_7cm_mean  data_type
# Baki 2026-04-14            11.312499                        2.305472       33141.066406                15.010000                  79.314529            1021.701904                2.4                 13.0           15.856354         79.000000            22.964998                     0.283333 historical
# Baki 2026-04-15            11.702085                        3.136395       41735.414062                20.240000                  69.572823            1024.161987                0.3                  3.0           15.484185         47.250000            28.199997                     0.277208 historical
# Baki 2026-04-16            13.097917                        3.106966       42755.191406                19.440001                  65.637993            1023.956787                0.0                  0.0           12.362475         20.416666            14.085001                     0.260625 historical
# Baki 2026-04-17            12.995834                        3.021810       42742.210938                21.790001                  80.436111            1024.379028                0.0                  0.0           16.036171         22.750000            25.874998                     0.239250 historical
# Baki 2026-04-18            13.668750                        2.861732       43815.843750                22.580000                  83.649406            1016.915588                0.0                  0.0           22.350464         27.541666            38.280003                     0.212958 historical
# STAGE 4: Feature Engineering (Staging -> Analytics)
# 🔧 Generating features from staging.weather_daily ...
# ✅ Features computed: day_of_year, precip_sum_7d, prev_soil_moisture
#
# Data now has 85 rows and 18 columns.
#
# 📊 Example of engineered data:
# city       date  temperature_2m_mean  et0_fao_evapotranspiration_sum  sunshine_duration  shortwave_radiation_sum  relative_humidity_2m_mean  surface_pressure_mean  precipitation_sum  precipitation_hours  wind_speed_10m_max  cloud_cover_mean  wind_gusts_10m_mean  soil_moisture_0_to_7cm_mean  data_type  day_of_year  precip_sum_7d  prev_soil_moisture
# Baki 2026-04-14            11.312499                        2.305472       33141.066406                15.010000                  79.314529            1021.701904                2.4                 13.0           15.856354         79.000000            22.964998                     0.283333 historical          104            2.4                 NaN
# Baki 2026-04-15            11.702085                        3.136395       41735.414062                20.240000                  69.572823            1024.161987                0.3                  3.0           15.484185         47.250000            28.199997                     0.277208 historical          105            2.7            0.283333
# Baki 2026-04-16            13.097917                        3.106966       42755.191406                19.440001                  65.637993            1023.956787                0.0                  0.0           12.362475         20.416666            14.085001                     0.260625 historical          106            2.7            0.277208
# Baki 2026-04-17            12.995834                        3.021810       42742.210938                21.790001                  80.436111            1024.379028                0.0                  0.0           16.036171         22.750000            25.874998                     0.239250 historical          107            2.7            0.260625
# Baki 2026-04-18            13.668750                        2.861732       43815.843750                22.580000                  83.649406            1016.915588                0.0                  0.0           22.350464         27.541666            38.280003                     0.212958 historical          108            2.7            0.239250
# Baki 2026-04-19            15.177083                        3.267373       41231.125000                21.450001                  80.289223            1006.191345                0.1                  1.0           20.803045         51.625000            34.079998                     0.188708 historical          109            2.8            0.212958
# Baki 2026-04-20            13.847917                        2.064010        8520.239258                 9.200000                  76.577911            1011.642517                1.8                  6.0           24.725605         95.208336            47.235001                     0.188417 historical          110            4.6            0.188708
# Baki 2026-04-21            10.787499                        1.553613       13218.458984                 9.220000                  83.323708            1015.477234                6.4                 11.0           22.158285         75.750000            38.565002                     0.244083 historical          111            8.6            0.188417
# Baki 2026-04-22            13.112499                        3.127617       43021.062500                20.930000                  80.909668            1013.233398                0.0                  0.0           18.501513         51.833332            25.094997                     0.240625 historical          112            8.3            0.244083
# Baki 2026-04-23            12.887501                        1.882021       21648.394531                13.040000                  86.022186            1011.448242                0.1                  1.0           19.380743         58.000000            29.189997                     0.225250 historical          113            8.4            0.240625
#
# ✅ Features written to analytics.weather_features.
# STAGE 5: Running Quality Checks
#
# ==================================================
# 📊 DATA QUALITY REPORT
# ==================================================
#     stage                  check_name status                    details
#       Raw               Row count > 0   PASS             85 rows loaded
#   Staging             Null ratio < 5%   PASS     All columns < 5% nulls
#   Staging            No gaps > 3 days   PASS    Max gap found: 1.0 days
#   Staging Temperature range [-50, 60]   PASS     0 invalid rows flagged
# Analytics        Feature completeness   PASS       All features present
#       Raw   Freshness (within 2 days)   PASS Latest data is -6 days old
# ==================================================
#
# 🎉 Pipeline completed successfully in 0.38 seconds.

# %%
# Run the pipeline in INCREMENTAL mode. 
# Because we just ran "full", it should detect that data is up to date and gracefully skip fetching!
# !python ../src/pipeline.py --mode incremental
# Out:
# 🚀 Starting Weather Pipeline in 'INCREMENTAL' mode.
# STAGE 1: Data Ingestion
# ⏩ Zerdab: Data is already up to date (Latest: 2026-04-30). Skipping fetch.
# ⏩ Quba: Data is already up to date (Latest: 2026-04-30). Skipping fetch.
# ⏩ Lenkeran: Data is already up to date (Latest: 2026-04-30). Skipping fetch.
# ⏩ Baki: Data is already up to date (Latest: 2026-04-30). Skipping fetch.
# ⏩ Saatli: Data is already up to date (Latest: 2026-04-30). Skipping fetch.
# STAGE 2: Loading to DuckDB Raw Layer
# ✅ Raw table contains 85 total rows.
# STAGE 3: Cleaning (Raw -> Staging)
# 🔄 Cleaning data from raw.weather_daily ...
# 📥 Raw data loaded: 85 rows, 15 columns
#
# 📅 Date continuity summary:
#        city start_date   end_date  ...  actual_days  missing_days  missing_list
# 0      Baki 2026-04-14 2026-04-30  ...           17             0            []
# 1  Lenkeran 2026-04-14 2026-04-30  ...           17             0            []
# 2      Quba 2026-04-14 2026-04-30  ...           17             0            []
# 3    Saatli 2026-04-14 2026-04-30  ...           17             0            []
# 4    Zerdab 2026-04-14 2026-04-30  ...           17             0            []
#
# [5 rows x 7 columns]
#
# ✅ Cleaned data written to staging.weather_daily
# 📊 Sample of cleaned data:
# city       date  temperature_2m_mean  et0_fao_evapotranspiration_sum  sunshine_duration  shortwave_radiation_sum  relative_humidity_2m_mean  surface_pressure_mean  precipitation_sum  precipitation_hours  wind_speed_10m_max  cloud_cover_mean  wind_gusts_10m_mean  soil_moisture_0_to_7cm_mean  data_type
# Baki 2026-04-14            11.312499                        2.305472       33141.066406                15.010000                  79.314529            1021.701904                2.4                 13.0           15.856354         79.000000            22.964998                     0.283333 historical
# Baki 2026-04-15            11.702085                        3.136395       41735.414062                20.240000                  69.572823            1024.161987                0.3                  3.0           15.484185         47.250000            28.199997                     0.277208 historical
# Baki 2026-04-16            13.097917                        3.106966       42755.191406                19.440001                  65.637993            1023.956787                0.0                  0.0           12.362475         20.416666            14.085001                     0.260625 historical
# Baki 2026-04-17            12.995834                        3.021810       42742.210938                21.790001                  80.436111            1024.379028                0.0                  0.0           16.036171         22.750000            25.874998                     0.239250 historical
# Baki 2026-04-18            13.668750                        2.861732       43815.843750                22.580000                  83.649406            1016.915588                0.0                  0.0           22.350464         27.541666            38.280003                     0.212958 historical
# STAGE 4: Feature Engineering (Staging -> Analytics)
# 🔧 Generating features from staging.weather_daily ...
# ✅ Features computed: day_of_year, precip_sum_7d, prev_soil_moisture
#
# Data now has 85 rows and 18 columns.
#
# 📊 Example of engineered data:
# city       date  temperature_2m_mean  et0_fao_evapotranspiration_sum  sunshine_duration  shortwave_radiation_sum  relative_humidity_2m_mean  surface_pressure_mean  precipitation_sum  precipitation_hours  wind_speed_10m_max  cloud_cover_mean  wind_gusts_10m_mean  soil_moisture_0_to_7cm_mean  data_type  day_of_year  precip_sum_7d  prev_soil_moisture
# Baki 2026-04-14            11.312499                        2.305472       33141.066406                15.010000                  79.314529            1021.701904                2.4                 13.0           15.856354         79.000000            22.964998                     0.283333 historical          104            2.4                 NaN
# Baki 2026-04-15            11.702085                        3.136395       41735.414062                20.240000                  69.572823            1024.161987                0.3                  3.0           15.484185         47.250000            28.199997                     0.277208 historical          105            2.7            0.283333
# Baki 2026-04-16            13.097917                        3.106966       42755.191406                19.440001                  65.637993            1023.956787                0.0                  0.0           12.362475         20.416666            14.085001                     0.260625 historical          106            2.7            0.277208
# Baki 2026-04-17            12.995834                        3.021810       42742.210938                21.790001                  80.436111            1024.379028                0.0                  0.0           16.036171         22.750000            25.874998                     0.239250 historical          107            2.7            0.260625
# Baki 2026-04-18            13.668750                        2.861732       43815.843750                22.580000                  83.649406            1016.915588                0.0                  0.0           22.350464         27.541666            38.280003                     0.212958 historical          108            2.7            0.239250
# Baki 2026-04-19            15.177083                        3.267373       41231.125000                21.450001                  80.289223            1006.191345                0.1                  1.0           20.803045         51.625000            34.079998                     0.188708 historical          109            2.8            0.212958
# Baki 2026-04-20            13.847917                        2.064010        8520.239258                 9.200000                  76.577911            1011.642517                1.8                  6.0           24.725605         95.208336            47.235001                     0.188417 historical          110            4.6            0.188708
# Baki 2026-04-21            10.787499                        1.553613       13218.458984                 9.220000                  83.323708            1015.477234                6.4                 11.0           22.158285         75.750000            38.565002                     0.244083 historical          111            8.6            0.188417
# Baki 2026-04-22            13.112499                        3.127617       43021.062500                20.930000                  80.909668            1013.233398                0.0                  0.0           18.501513         51.833332            25.094997                     0.240625 historical          112            8.3            0.244083
# Baki 2026-04-23            12.887501                        1.882021       21648.394531                13.040000                  86.022186            1011.448242                0.1                  1.0           19.380743         58.000000            29.189997                     0.225250 historical          113            8.4            0.240625
#
# ✅ Features written to analytics.weather_features.
# STAGE 5: Running Quality Checks
#
# ==================================================
# 📊 DATA QUALITY REPORT
# ==================================================
#     stage                  check_name status                    details
#       Raw               Row count > 0   PASS             85 rows loaded
#   Staging             Null ratio < 5%   PASS     All columns < 5% nulls
#   Staging            No gaps > 3 days   PASS    Max gap found: 1.0 days
#   Staging Temperature range [-50, 60]   PASS     0 invalid rows flagged
# Analytics        Feature completeness   PASS       All features present
#       Raw   Freshness (within 2 days)   PASS Latest data is -6 days old
# ==================================================
#
# 🎉 Pipeline completed successfully in 0.29 seconds.

# %%
# Let's inspect the log file generated by the pipeline
with open('../logs/pipeline.log', 'r', encoding='utf-8') as f:
    logs = f.readlines()
    for line in logs[-15:]: # Show the last 15 log entries
        print(line.strip())
# Out:
# 2026-04-24 21:53:01,268 - INFO - STAGE 5: Running Quality Checks
# 2026-04-24 21:53:01,296 - INFO - 🎉 Pipeline completed successfully in 0.2 seconds.
# 2026-04-24 23:16:30,684 - INFO - 🚀 Starting Weather Pipeline in 'INCREMENTAL' mode.
# 2026-04-24 23:16:30,729 - INFO - STAGE 1: Data Ingestion
# 2026-04-24 23:16:30,812 - INFO - ⏩ Zerdab: Data is already up to date (Latest: 2026-04-30). Skipping fetch.
# 2026-04-24 23:16:30,817 - INFO - ⏩ Quba: Data is already up to date (Latest: 2026-04-30). Skipping fetch.
# 2026-04-24 23:16:30,824 - INFO - ⏩ Lenkeran: Data is already up to date (Latest: 2026-04-30). Skipping fetch.
# 2026-04-24 23:16:30,849 - INFO - ⏩ Baki: Data is already up to date (Latest: 2026-04-30). Skipping fetch.
# 2026-04-24 23:16:30,855 - INFO - ⏩ Saatli: Data is already up to date (Latest: 2026-04-30). Skipping fetch.
# 2026-04-24 23:16:30,855 - INFO - STAGE 2: Loading to DuckDB Raw Layer
# 2026-04-24 23:16:30,860 - INFO - ✅ Raw table contains 85 total rows.
# 2026-04-24 23:16:30,861 - INFO - STAGE 3: Cleaning (Raw -> Staging)
# 2026-04-24 23:16:31,295 - INFO - STAGE 4: Feature Engineering (Staging -> Analytics)
# 2026-04-24 23:16:31,396 - INFO - STAGE 5: Running Quality Checks
# 2026-04-24 23:16:31,463 - INFO - 🎉 Pipeline completed successfully in 0.78 seconds.
